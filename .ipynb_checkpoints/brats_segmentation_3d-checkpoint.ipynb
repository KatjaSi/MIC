# %%
# !python -c "import monai" || pip install -q "monai-weekly[nibabel, tqdm]"
# !python -c "import matplotlib" || pip install -q matplotlib
# %matplotlib inline

# %%
# !pip install monai[all]
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: monai[all] in /cluster/home/katjasi/.local/lib/python3.9/site-packages (1.3.0)
# Requirement already satisfied: torch>=1.9 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from monai[all]) (2.0.1+cu118)
# Requirement already satisfied: numpy>=1.20 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from monai[all]) (1.24.3)
# Requirement already satisfied: lmdb in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from monai[all]) (1.4.1)
# Requirement already satisfied: ninja in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from monai[all]) (1.11.1.1)
# Requirement already satisfied: pydicom in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from monai[all]) (2.4.3)
# Requirement already satisfied: pytorch-ignite==0.4.11 in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from monai[all]) (0.4.11)
# Requirement already satisfied: torchvision in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from monai[all]) (0.15.2)
# Requirement already satisfied: tifffile in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from monai[all]) (2021.7.2)
# Requirement already satisfied: onnx>=1.13.0 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from monai[all]) (1.14.0)
# Requirement already satisfied: mlflow>=1.28.0 in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from monai[all]) (2.8.0)
# Requirement already satisfied: pynrrd in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from monai[all]) (1.0.0)
# Requirement already satisfied: fire in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from monai[all]) (0.5.0)
# Requirement already satisfied: pandas in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from monai[all]) (1.4.2)
# Requirement already satisfied: matplotlib in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from monai[all]) (3.7.1)
# Requirement already satisfied: transformers<4.22 in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from monai[all]) (4.21.3)
# Requirement already satisfied: itk>=5.2 in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from monai[all]) (5.3.0)
# Requirement already satisfied: psutil in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from monai[all]) (5.8.0)
# Requirement already satisfied: einops in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from monai[all]) (0.7.0)
# Requirement already satisfied: nibabel in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from monai[all]) (5.1.0)
# Requirement already satisfied: pillow in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from monai[all]) (9.0.1)
# Requirement already satisfied: zarr in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from monai[all]) (2.16.1)
# Requirement already satisfied: lpips==0.1.4 in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from monai[all]) (0.1.4)
# Requirement already satisfied: optuna in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from monai[all]) (3.4.0)
# Requirement already satisfied: nni in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from monai[all]) (3.0)
# Requirement already satisfied: gdown>=4.4.0 in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from monai[all]) (4.7.1)
# Requirement already satisfied: cucim>=23.2.0 in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from monai[all]) (23.10.0)
# Requirement already satisfied: tensorboard in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from monai[all]) (2.13.0)
# Requirement already satisfied: tensorboardX in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from monai[all]) (2.6)
# Requirement already satisfied: onnxruntime in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from monai[all]) (1.16.1)
# Requirement already satisfied: imagecodecs in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from monai[all]) (2021.8.26)
# Requirement already satisfied: jsonschema in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from monai[all]) (4.4.0)
# Requirement already satisfied: openslide-python==1.1.2 in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from monai[all]) (1.1.2)
# Requirement already satisfied: scikit-image>=0.14.2 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from monai[all]) (0.19.2)
# Requirement already satisfied: tqdm>=4.47.0 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from monai[all]) (4.64.0)
# Requirement already satisfied: clearml>=1.10.0rc0 in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from monai[all]) (1.13.2rc2)
# Requirement already satisfied: h5py in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from monai[all]) (3.6.0)
# Requirement already satisfied: nvidia-ml-py in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from monai[all]) (12.535.108)
# Requirement already satisfied: scipy>=1.7.1 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from monai[all]) (1.10.1)
# Requirement already satisfied: pyyaml in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from monai[all]) (6.0)
# Requirement already satisfied: packaging in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from pytorch-ignite==0.4.11->monai[all]) (21.3)
# Requirement already satisfied: furl>=2.0.0 in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from clearml>=1.10.0rc0->monai[all]) (2.1.3)
# Requirement already satisfied: pyparsing>=2.0.3 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from clearml>=1.10.0rc0->monai[all]) (3.0.4)
# Requirement already satisfied: six>=1.13.0 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from clearml>=1.10.0rc0->monai[all]) (1.16.0)
# Requirement already satisfied: pathlib2>=2.3.0 in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from clearml>=1.10.0rc0->monai[all]) (2.3.7.post1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from clearml>=1.10.0rc0->monai[all]) (2.8.2)
# Requirement already satisfied: requests>=2.20.0 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from clearml>=1.10.0rc0->monai[all]) (2.27.1)
# Requirement already satisfied: urllib3>=1.21.1 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from clearml>=1.10.0rc0->monai[all]) (1.26.9)
# Requirement already satisfied: pyjwt<2.9.0,>=2.4.0 in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from clearml>=1.10.0rc0->monai[all]) (2.8.0)
# Requirement already satisfied: attrs>=18.0 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from clearml>=1.10.0rc0->monai[all]) (21.4.0)
# Requirement already satisfied: lazy-loader>=0.1 in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from cucim>=23.2.0->monai[all]) (0.3)
# Requirement already satisfied: click in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from cucim>=23.2.0->monai[all]) (8.0.4)
# Requirement already satisfied: orderedmultidict>=1.0.1 in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from furl>=2.0.0->clearml>=1.10.0rc0->monai[all]) (1.0.1)
# Requirement already satisfied: filelock in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from gdown>=4.4.0->monai[all]) (3.6.0)
# Requirement already satisfied: beautifulsoup4 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from gdown>=4.4.0->monai[all]) (4.11.1)
# Requirement already satisfied: itk-segmentation==5.3.0 in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from itk>=5.2->monai[all]) (5.3.0)
# Requirement already satisfied: itk-io==5.3.0 in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from itk>=5.2->monai[all]) (5.3.0)
# Requirement already satisfied: itk-registration==5.3.0 in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from itk>=5.2->monai[all]) (5.3.0)
# Requirement already satisfied: itk-filtering==5.3.0 in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from itk>=5.2->monai[all]) (5.3.0)
# Requirement already satisfied: itk-numerics==5.3.0 in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from itk>=5.2->monai[all]) (5.3.0)
# Requirement already satisfied: itk-core==5.3.0 in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from itk>=5.2->monai[all]) (5.3.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from jsonschema->monai[all]) (0.18.0)
# Requirement already satisfied: pyarrow<14,>=4.0.0 in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from mlflow>=1.28.0->monai[all]) (13.0.0)
# Requirement already satisfied: importlib-metadata!=4.7.0,<7,>=3.7.0 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from mlflow>=1.28.0->monai[all]) (4.11.3)
# Requirement already satisfied: gunicorn<22 in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from mlflow>=1.28.0->monai[all]) (21.2.0)
# Requirement already satisfied: querystring-parser<2 in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from mlflow>=1.28.0->monai[all]) (1.2.4)
# Requirement already satisfied: docker<7,>=4.0.0 in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from mlflow>=1.28.0->monai[all]) (6.1.3)
# Requirement already satisfied: protobuf<5,>=3.12.0 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from mlflow>=1.28.0->monai[all]) (3.20.3)
# Requirement already satisfied: gitpython<4,>=2.1.0 in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from mlflow>=1.28.0->monai[all]) (3.1.40)
# Requirement already satisfied: alembic!=1.10.0,<2 in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from mlflow>=1.28.0->monai[all]) (1.12.1)
# Requirement already satisfied: pytz<2024 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from mlflow>=1.28.0->monai[all]) (2021.3)
# Requirement already satisfied: entrypoints<1 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from mlflow>=1.28.0->monai[all]) (0.4)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from mlflow>=1.28.0->monai[all]) (0.4.4)
# Requirement already satisfied: cloudpickle<3 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from mlflow>=1.28.0->monai[all]) (2.0.0)
# Requirement already satisfied: databricks-cli<1,>=0.8.7 in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from mlflow>=1.28.0->monai[all]) (0.18.0)
# Requirement already satisfied: Jinja2<4,>=2.11 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from mlflow>=1.28.0->monai[all]) (2.11.3)
# Requirement already satisfied: Flask<4 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from mlflow>=1.28.0->monai[all]) (1.1.2)
# Requirement already satisfied: scikit-learn<2 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from mlflow>=1.28.0->monai[all]) (1.0.2)
# Requirement already satisfied: markdown<4,>=3.3 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from mlflow>=1.28.0->monai[all]) (3.3.4)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from mlflow>=1.28.0->monai[all]) (1.4.32)
# Requirement already satisfied: typing-extensions>=4 in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from alembic!=1.10.0,<2->mlflow>=1.28.0->monai[all]) (4.8.0)
# Requirement already satisfied: Mako in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from alembic!=1.10.0,<2->mlflow>=1.28.0->monai[all]) (1.2.4)
# Requirement already satisfied: tabulate>=0.7.7 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from databricks-cli<1,>=0.8.7->mlflow>=1.28.0->monai[all]) (0.8.9)
# Requirement already satisfied: oauthlib>=3.1.0 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from databricks-cli<1,>=0.8.7->mlflow>=1.28.0->monai[all]) (3.2.2)
# Requirement already satisfied: websocket-client>=0.32.0 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from docker<7,>=4.0.0->mlflow>=1.28.0->monai[all]) (0.58.0)
# Requirement already satisfied: itsdangerous>=0.24 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from Flask<4->mlflow>=1.28.0->monai[all]) (2.0.1)
# Requirement already satisfied: Werkzeug>=0.15 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from Flask<4->mlflow>=1.28.0->monai[all]) (2.0.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from gitpython<4,>=2.1.0->mlflow>=1.28.0->monai[all]) (4.0.11)
# Requirement already satisfied: smmap<6,>=3.0.1 in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=2.1.0->mlflow>=1.28.0->monai[all]) (5.0.1)
# Requirement already satisfied: zipp>=0.5 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from importlib-metadata!=4.7.0,<7,>=3.7.0->mlflow>=1.28.0->monai[all]) (3.7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from Jinja2<4,>=2.11->mlflow>=1.28.0->monai[all]) (2.0.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from matplotlib->monai[all]) (5.12.0)
# Requirement already satisfied: contourpy>=1.0.1 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from matplotlib->monai[all]) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from matplotlib->monai[all]) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from matplotlib->monai[all]) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from matplotlib->monai[all]) (0.11.0)
# Requirement already satisfied: certifi>=2017.4.17 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from requests>=2.20.0->clearml>=1.10.0rc0->monai[all]) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from requests>=2.20.0->clearml>=1.10.0rc0->monai[all]) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from requests>=2.20.0->clearml>=1.10.0rc0->monai[all]) (2.0.4)
# Requirement already satisfied: imageio>=2.4.1 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from scikit-image>=0.14.2->monai[all]) (2.9.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from scikit-image>=0.14.2->monai[all]) (1.3.0)
# Requirement already satisfied: networkx>=2.2 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from scikit-image>=0.14.2->monai[all]) (2.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from scikit-learn<2->mlflow>=1.28.0->monai[all]) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from scikit-learn<2->mlflow>=1.28.0->monai[all]) (1.1.0)
# Requirement already satisfied: greenlet!=0.4.17 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from sqlalchemy<3,>=1.4.0->mlflow>=1.28.0->monai[all]) (1.1.1)
# Requirement already satisfied: sympy in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from torch>=1.9->monai[all]) (1.10.1)
# Requirement already satisfied: triton==2.0.0 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from torch>=1.9->monai[all]) (2.0.0)
# Requirement already satisfied: lit in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from triton==2.0.0->torch>=1.9->monai[all]) (15.0.7)
# Requirement already satisfied: cmake in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from triton==2.0.0->torch>=1.9->monai[all]) (3.25.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from transformers<4.22->monai[all]) (0.12.1)
# Requirement already satisfied: regex!=2019.12.17 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from transformers<4.22->monai[all]) (2022.3.15)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from transformers<4.22->monai[all]) (0.14.1)
# Requirement already satisfied: fsspec in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.1.0->transformers<4.22->monai[all]) (2023.5.0)
# Requirement already satisfied: soupsieve>1.2 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from beautifulsoup4->gdown>=4.4.0->monai[all]) (2.3.1)
# Requirement already satisfied: termcolor in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from fire->monai[all]) (2.3.0)
# Requirement already satisfied: schema in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from nni->monai[all]) (0.7.5)
# Requirement already satisfied: json-tricks>=3.15.5 in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from nni->monai[all]) (3.17.3)
# Requirement already satisfied: responses in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from nni->monai[all]) (0.23.1)
# Requirement already satisfied: PythonWebHDFS in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from nni->monai[all]) (0.2.3)
# Requirement already satisfied: astor in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from nni->monai[all]) (0.8.1)
# Requirement already satisfied: prettytable in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from nni->monai[all]) (3.9.0)
# Requirement already satisfied: colorama in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from nni->monai[all]) (0.4.4)
# Requirement already satisfied: typeguard<4.1.3,>=3.0.0 in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from nni->monai[all]) (4.1.2)
# Requirement already satisfied: websockets>=10.1 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from nni->monai[all]) (11.0.3)
# Requirement already satisfied: flatbuffers in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from onnxruntime->monai[all]) (23.5.26)
# Requirement already satisfied: coloredlogs in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from onnxruntime->monai[all]) (15.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from coloredlogs->onnxruntime->monai[all]) (10.0)
# Requirement already satisfied: colorlog in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from optuna->monai[all]) (6.7.0)
# Requirement already satisfied: wcwidth in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from prettytable->nni->monai[all]) (0.2.5)
# Requirement already satisfied: nptyping in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from pynrrd->monai[all]) (2.5.0)
# Requirement already satisfied: simplejson in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from PythonWebHDFS->nni->monai[all]) (3.19.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from requests>=2.20.0->clearml>=1.10.0rc0->monai[all]) (1.7.1)
# Requirement already satisfied: types-PyYAML in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from responses->nni->monai[all]) (6.0.12.12)
# Requirement already satisfied: contextlib2>=0.5.5 in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from schema->nni->monai[all]) (21.6.0)
# Requirement already satisfied: mpmath>=0.19 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from sympy->torch>=1.9->monai[all]) (1.2.1)
# Requirement already satisfied: setuptools>=41.0.0 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from tensorboard->monai[all]) (61.2.0)
# Requirement already satisfied: grpcio>=1.48.2 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from tensorboard->monai[all]) (1.54.0)
# Requirement already satisfied: wheel>=0.26 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from tensorboard->monai[all]) (0.37.1)
# Requirement already satisfied: absl-py>=0.4 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from tensorboard->monai[all]) (1.4.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from tensorboard->monai[all]) (1.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from tensorboard->monai[all]) (0.7.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from tensorboard->monai[all]) (2.18.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard->monai[all]) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard->monai[all]) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard->monai[all]) (4.2.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->monai[all]) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->monai[all]) (0.4.8)
# Requirement already satisfied: asciitree in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from zarr->monai[all]) (0.3.3)
# Requirement already satisfied: fasteners in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from zarr->monai[all]) (0.19)
# Requirement already satisfied: numcodecs>=0.10.0 in /cluster/home/katjasi/.local/lib/python3.9/site-packages (from zarr->monai[all]) (0.12.1)

# %%
import os
import shutil
import tempfile
import time
import matplotlib.pyplot as plt
import SimpleITK as sitk

import numpy as np

# %%
from unet3d import UNet3D
# Out:
# UNet3D(
#   (encoder): Sequential(
#     (0): Conv3d(4, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (4): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (middle): Sequential(
#     (0): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (4): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#   )
#   (decoder): Sequential(
#     (0): Conv3d(192, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (4): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): ConvTranspose3d(64, 3, kernel_size=(2, 2, 2), stride=(2, 2, 2))
#   )
# )

# %%
from monai.apps import DecathlonDataset
from monai.config import print_config
from monai.data import DataLoader, decollate_batch
from monai.handlers.utils import from_engine
from monai.losses import DiceLoss
from monai.inferers import sliding_window_inference
from monai.metrics import DiceMetric
from monai.networks.nets import SegResNet
from monai.transforms import (
    Activations,
    Activationsd,
    AsDiscrete,
    AsDiscreted,
    Compose,
    Invertd,
    LoadImaged,
    ToTensor,
    ToMetaTensorD,
    MapTransform,
    NormalizeIntensityd,
    Orientationd,
    RandFlipd,
    RandScaleIntensityd,
    RandShiftIntensityd,
    RandSpatialCropd,
    Spacingd,
    EnsureTyped,
    EnsureChannelFirstd,
)
from monai.utils import set_determinism

import torch

print_config()
# Out:
# MONAI version: 1.3.0
# Numpy version: 1.24.3
# Pytorch version: 2.0.1+cu118
# MONAI flags: HAS_EXT = False, USE_COMPILED = False, USE_META_DICT = False
# MONAI rev id: 865972f7a791bf7b42efbcd87c8402bd865b329e
# MONAI __file__: /cluster/home/<username>/.local/lib/python3.9/site-packages/monai/__init__.py
#
# Optional dependencies:
# Pytorch Ignite version: 0.4.11
# ITK version: 5.3.0
# Nibabel version: 5.1.0
# scikit-image version: 0.19.2
# scipy version: 1.10.1
# Pillow version: 9.0.1
# Tensorboard version: 2.13.0
# gdown version: 4.7.1
# TorchVision version: NOT INSTALLED or UNKNOWN VERSION.
# tqdm version: 4.64.0
# lmdb version: 1.4.1
# psutil version: 5.8.0
# pandas version: 1.4.2
# einops version: 0.7.0
# transformers version: 4.21.3
# mlflow version: 2.8.0
# pynrrd version: 1.0.0
# clearml version: 1.13.2rc2
#
# For details about installing the optional dependencies, please visit:
#     https://docs.monai.io/en/latest/installation.html#installing-the-recommended-dependencies

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
root_dir = os.getcwd()

# %%
#directory = os.environ.get("MONAI_DATA_DIRECTORY")
#root_dir = tempfile.mkdtemp() if directory is None else directory
print(root_dir)
# Out:
# /cluster/home/katjasi/MIC

# %%
set_determinism(seed=0)

# %%
class ConvertToMultiChannelBasedOnBratsClassesd(MapTransform):
    """
    Convert labels to multi channels based on brats classes:
    label 1 is the peritumoral edema
    label 2 is the GD-enhancing tumor
    label 3 is the necrotic and non-enhancing tumor core
    The possible classes are TC (Tumor core), WT (Whole tumor)
    and ET (Enhancing tumor).

    """

    def __call__(self, data):
        d = dict(data)
        for key in self.keys:
            result = []
            # merge label 2 and label 3 to construct TC
            result.append(np.logical_or(d[key] == 2, d[key] == 3))
            # merge labels 1, 2 and 3 to construct WT
            result.append(np.logical_or(np.logical_or(d[key] == 2, d[key] == 3), d[key] == 1))
            # label 2 is ET
            result.append(d[key] == 2)
            d[key] = np.stack(result, axis=0)#.float()
        return d

# %%
train_transform = Compose(
    [
        # load 4 Nifti images and stack them together
        LoadImaged(keys=["image", "label"]),
        EnsureChannelFirstd(keys="image"),
        EnsureTyped(keys=["image", "label"]),
        ConvertToMultiChannelBasedOnBratsClassesd(keys="label"),
        Orientationd(keys=["image", "label"], axcodes="RAS"),
        Spacingd(
            keys=["image", "label"],
            pixdim=(1.0, 1.0, 1.0),
            mode=("bilinear", "nearest"),
        ),
        RandSpatialCropd(keys=["image", "label"], roi_size=[224, 224, 144], random_size=False),
        RandFlipd(keys=["image", "label"], prob=0.5, spatial_axis=0),
        RandFlipd(keys=["image", "label"], prob=0.5, spatial_axis=1),
        RandFlipd(keys=["image", "label"], prob=0.5, spatial_axis=2),
        NormalizeIntensityd(keys="image", nonzero=True, channel_wise=True),
        RandScaleIntensityd(keys="image", factors=0.1, prob=1.0),
        RandShiftIntensityd(keys="image", offsets=0.1, prob=1.0),
    ]
)
val_transform = Compose(
    [
        LoadImaged(keys=["image", "label"]),  
        EnsureChannelFirstd(keys="image"),
        EnsureTyped(keys=["image", "label"]),
        ConvertToMultiChannelBasedOnBratsClassesd(keys="label"),
        Orientationd(keys=["image", "label"], axcodes="RAS"),
        Spacingd(
            keys=["image", "label"],
            pixdim=(1.0, 1.0, 1.0),
            mode=("bilinear", "nearest"),
        ),
        NormalizeIntensityd(keys="image", nonzero=True, channel_wise=True)
    ]
)

# %%
# here we don't cache any data in case out of memory issue
train_ds = DecathlonDataset(
    root_dir=os.getcwd(), #current
    task="Task01_BrainTumour",
    transform=train_transform,
    section="training",
    download=False,
    cache_rate=0.0,
    num_workers=2,
)

# %%
train_loader = DataLoader(train_ds, batch_size=1, shuffle=True, num_workers=2)

# %%
val_ds = DecathlonDataset(
    root_dir=os.getcwd(),
    task="Task01_BrainTumour",
    transform=val_transform,
    section="validation",
    download=False,
    cache_rate=0.0,
    num_workers=2,
)
val_loader = DataLoader(val_ds, batch_size=1, shuffle=False, num_workers=2)

# %%
# pick one image from DecathlonDataset to visualize and check the 4 channels
#val_data_example = val_ds.data[2]['image']
val_data_example = next(iter(val_loader))
#print(val_data_example)

# %%
#image = sitk.ReadImage(val_data_example['image'])
image = val_data_example['image']
#image_array = sitk.GetArrayFromImage(image)
#image_array.shape
print(image.shape)
# Out:
# torch.Size([1, 4, 240, 240, 155])

# %%
plt.figure("image", (24, 6))
for i in range(4):
    plt.subplot(1, 4, i + 1)
    plt.title(f"image channel {i}")
    plt.imshow(image[0,i, :, :, 60].detach().cpu(), cmap="gray")
plt.show()

# %%
# also visualize the 3 channels label corresponding to this image
label = val_data_example['label']
label.shape
# Out:
# torch.Size([1, 3, 240, 240, 155])

# %%
plt.figure("label", (18, 6))
for i in range(3):
    plt.subplot(1, 3, i + 1)
    plt.title(f"label channel {i}")
    plt.imshow(label[0, i, :, :, 60].detach().cpu())
plt.show()

# %% [markdown]
# ### Model, Loss, Optimizer

# %%
max_epochs = 300
val_interval = 1
VAL_AMP = True

# standard PyTorch program style: create SegResNet, DiceLoss and Adam optimizer
device = torch.device("cuda")
#model = SegResNet(
 #   blocks_down=[1, 2, 2, 4],
  #  blocks_up=[1, 1, 1],
  #  init_filters=16,
  #  in_channels=4,
  #  out_channels=3,
  #  dropout_prob=0.2,
#).to(device)
model = UNet3D(4,3).to(device)
loss_function = DiceLoss(smooth_nr=0, smooth_dr=1e-5, squared_pred=True, to_onehot_y=False, sigmoid=True)
optimizer = torch.optim.Adam(model.parameters(), 1e-4, weight_decay=1e-5)
lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=max_epochs)

dice_metric = DiceMetric(include_background=True, reduction="mean")
dice_metric_batch = DiceMetric(include_background=True, reduction="mean_batch")

post_trans = Compose([Activations(sigmoid=True), AsDiscrete(threshold=0.5)])


# define inference method
def inference(input):
    def _compute(input):
        return sliding_window_inference(
            inputs=input,
            roi_size=(240, 240, 160),
            sw_batch_size=1,
            predictor=model,
            overlap=0.5,
        )

    if VAL_AMP:
        with torch.cuda.amp.autocast():
            return _compute(input)
    else:
        return _compute(input)


# use amp to accelerate training
scaler = torch.cuda.amp.GradScaler()
# enable cuDNN benchmark
torch.backends.cudnn.benchmark = True

# %% [markdown]
# ### Train Loop

# %%
best_metric = -1
best_metric_epoch = -1
best_metrics_epochs_and_time = [[], [], []]
epoch_loss_values = []
metric_values = []
metric_values_tc = []
metric_values_wt = []
metric_values_et = []

total_start = time.time()
for epoch in range(max_epochs):
    epoch_start = time.time()
    print("-" * 10)
    print(f"epoch {epoch + 1}/{max_epochs}")
    model.train()
    epoch_loss = 0
    step = 0
    for batch_data in train_loader:
        step_start = time.time()
        step += 1
        inputs, labels = (
            batch_data["image"].to(device),
            batch_data["label"].to(device),
        )
        optimizer.zero_grad()
        with torch.cuda.amp.autocast():
            outputs = model(inputs)
            loss = loss_function(outputs, labels)
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        epoch_loss += loss.item()
      #  print(
       #     f"{step}/{len(train_ds) // train_loader.batch_size}"
        #    f", train_loss: {loss.item():.4f}"
         #   f", step time: {(time.time() - step_start):.4f}"
        #)
    lr_scheduler.step()
    epoch_loss /= step
    epoch_loss_values.append(epoch_loss)
    print(f"epoch {epoch + 1} average loss: {epoch_loss:.4f}")
    
    if (epoch + 1) % val_interval == 0:
        model.eval()
        with torch.no_grad():
            for val_data in val_loader:
                val_inputs, val_labels = (
                    val_data["image"].to(device),
                    val_data["label"].to(device),
                )
                val_outputs = inference(val_inputs)
                val_outputs = [post_trans(i) for i in decollate_batch(val_outputs)]
                dice_metric(y_pred=val_outputs, y=val_labels)
                dice_metric_batch(y_pred=val_outputs, y=val_labels)

            metric = dice_metric.aggregate().item()
            metric_values.append(metric)
            metric_batch = dice_metric_batch.aggregate()
            metric_tc = metric_batch[0].item()
            metric_values_tc.append(metric_tc)
            metric_wt = metric_batch[1].item()
            metric_values_wt.append(metric_wt)
            metric_et = metric_batch[2].item()
            metric_values_et.append(metric_et)
            dice_metric.reset()
            dice_metric_batch.reset()

            if metric > best_metric:
                best_metric = metric
                best_metric_epoch = epoch + 1
                best_metrics_epochs_and_time[0].append(best_metric)
                best_metrics_epochs_and_time[1].append(best_metric_epoch)
                best_metrics_epochs_and_time[2].append(time.time() - total_start)
                torch.save(
                    model.state_dict(),
                    os.path.join(root_dir, "best_metric_model.pth"),
                )
                print("saved new best metric model")
            print(
                f"current epoch: {epoch + 1} current mean dice: {metric:.4f}"
                f" tc: {metric_tc:.4f} wt: {metric_wt:.4f} et: {metric_et:.4f}"
                f"\nbest mean dice: {best_metric:.4f}"
                f" at epoch: {best_metric_epoch}"
            )
    print(f"time consuming of epoch {epoch + 1} is: {(time.time() - epoch_start):.4f}")
total_time = time.time() - total_start
# Out:
# ----------
# epoch 1/300
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [21], in <cell line: 11>()
#      27     outputs = model(inputs)
#      28     loss = loss_function(outputs, labels)
# ---> 29 scaler.scale(loss).backward()
#      30 scaler.step(optimizer)
#      31 scaler.update()
#
# File /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages/torch/_tensor.py:478, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     431 r"""Computes the gradient of current tensor w.r.t. graph leaves.
#     432
#     433 The graph is differentiated using the chain rule. If the tensor is
#    (...)
#     475         used to compute the attr::tensors.
#     476 """
#     477 if has_torch_function_unary(self):
# --> 478     return handle_torch_function(
#     479         Tensor.backward,
#     480         (self,),
#     481         self,
#     482         gradient=gradient,
#     483         retain_graph=retain_graph,
#     484         create_graph=create_graph,
#     485         inputs=inputs,
#     486     )
#     487 torch.autograd.backward(
#     488     self, gradient, retain_graph, create_graph, inputs=inputs
#     489 )
#
# File /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages/torch/overrides.py:1551, in handle_torch_function(public_api, relevant_args, *args, **kwargs)
#    1545     warnings.warn("Defining your `__torch_function__ as a plain method is deprecated and "
#    1546                   "will be an error in future, please define it as a classmethod.",
#    1547                   DeprecationWarning)
#    1549 # Use `public_api` instead of `implementation` so __torch_function__
#    1550 # implementations can do equality/identity comparisons.
# -> 1551 result = torch_func_method(public_api, types, args, kwargs)
#    1553 if result is not NotImplemented:
#    1554     return result
#
# File ~/.local/lib/python3.9/site-packages/monai/data/meta_tensor.py:282, in MetaTensor.__torch_function__(cls, func, types, args, kwargs)
#     280 if kwargs is None:
#     281     kwargs = {}
# --> 282 ret = super().__torch_function__(func, types, args, kwargs)
#     283 # if `out` has been used as argument, metadata is not copied, nothing to do.
#     284 # if "out" in kwargs:
#     285 #     return ret
#     286 if _not_requiring_metadata(ret):
#
# File /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages/torch/_tensor.py:1295, in Tensor.__torch_function__(cls, func, types, args, kwargs)
#    1292     return NotImplemented
#    1294 with _C.DisableTorchFunctionSubclass():
# -> 1295     ret = func(*args, **kwargs)
#    1296     if func in get_default_nowrap_functions():
#    1297         return ret
#
# File /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages/torch/_tensor.py:487, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     477 if has_torch_function_unary(self):
#     478     return handle_torch_function(
#     479         Tensor.backward,
#     480         (self,),
#    (...)
#     485         inputs=inputs,
#     486     )
# --> 487 torch.autograd.backward(
#     488     self, gradient, retain_graph, create_graph, inputs=inputs
#     489 )
#
# File /cluster/apps/eb/software/Anaconda3/2022.05/lib/python3.9/site-packages/torch/autograd/__init__.py:200, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     195     retain_graph = create_graph
#     197 # The reason we repeat same the comment below is that
#     198 # some Python versions print out the first line of a multi-line function
#     199 # calls in the traceback and some print out the last line
# --> 200 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     201     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     202     allow_unreachable=True, accumulate_grad=True)
#
# RuntimeError: cuDNN error: CUDNN_STATUS_EXECUTION_FAILED

# %%
print(f"train completed, best_metric: {best_metric:.4f} at epoch: {best_metric_epoch}, total time: {total_time}.")
